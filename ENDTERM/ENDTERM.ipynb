# %% [markdown]
# # FOOD NUTRITION <hr style="border:2.5px solid #126782"></hr>

# %% [markdown]
# **Name**: Ralph Michael A. De La Torre<br>**Section**: BS CpE 2A

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Overview of Dataset

# %%
df = pd.read_csv(r"raw\Food_and_Nutrition.csv",delimiter = ",")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1698 entries, 0 to 1697
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Ages                  1698 non-null   int64
#  1   Gender                1698 non-null   object
#  2   Height                1645 non-null   float64
#  3   Weight                1648 non-null   float64
#  4   Activity Level        1698 non-null   object
#  5   Dietary Preference    1698 non-null   object
#  6   Daily Calorie Target  1640 non-null   float64
#  7   Protein               1655 non-null   float64
#  8   Sugar                 1653 non-null   float64
#  9   Sodium                1658 non-null   float64
#  10  Calories              1644 non-null   float64
#  11  Carbohydrates         1648 non-null   float64
#  12  Fiber                 1641 non-null   float64
#  13  Fat                   1648 non-null   float64
# dtypes: float64(10), int64(1), object(3)
# ...

# %%
df.head()
# Out:
#    Ages  Gender  Height  Weight     Activity Level Dietary Preference  \
# 0    25    Male   180.0    80.0  Moderately Active           Omnivore
# 1    32  Female   165.0    65.0     Lightly Active         Vegetarian
# 2    48    Male   175.0    95.0          Sedentary              Vegan
# 3    55  Female   160.0    70.0        Very Active           Omnivore
# 4    62    Male   170.0    85.0          Sedentary         Vegetarian
#
#    Daily Calorie Target  Protein  Sugar  Sodium  Calories  Carbohydrates  \
# 0                2000.0    120.0  125.0    24.0    2020.0          250.0
# 1                1600.0     80.0  100.0    16.0    1480.0          200.0
# 2                2200.0    100.0    NaN    20.0    2185.0          300.0
# 3                2500.0    140.0  175.0    28.0       NaN          350.0
# 4                2000.0     80.0  125.0    16.0    1815.0          250.0
#
#    Fiber   Fat
# 0   30.0  60.0
# 1   24.0  40.0
# 2   36.0  65.0
# 3   42.0  80.0
# 4   30.0  55.0

# %% [markdown]
# # Dropping of NaN Values

# %% [markdown]
# Determine the count of **NaN** Values

# %%
df_w = df
df_w.isna().sum()
# Out:
# Ages                     0
# Gender                   0
# Height                  53
# Weight                  50
# Activity Level           0
# Dietary Preference       0
# Daily Calorie Target    58
# Protein                 43
# Sugar                   45
# Sodium                  40
# Calories                54
# Carbohydrates           50
# Fiber                   57
# Fat                     50
# dtype: int64

# %%
df_w = df_w.dropna(subset=['Height'])
df_w.isna().sum()
# Out:
# Ages                     0
# Gender                   0
# Height                   0
# Weight                  49
# Activity Level           0
# Dietary Preference       0
# Daily Calorie Target    56
# Protein                 43
# Sugar                   44
# Sodium                  38
# Calories                51
# Carbohydrates           48
# Fiber                   55
# Fat                     48
# dtype: int64

# %%
df_w = df_w.dropna(subset=['Weight'])
df_w.isna().sum()
# Out:
# Ages                     0
# Gender                   0
# Height                   0
# Weight                   0
# Activity Level           0
# Dietary Preference       0
# Daily Calorie Target    55
# Protein                 42
# Sugar                   44
# Sodium                  36
# Calories                50
# Carbohydrates           48
# Fiber                   54
# Fat                     48
# dtype: int64

# %%
df_w = df_w.dropna(subset=['Daily Calorie Target'])
df_w.isna().sum()
# Out:
# Ages                     0
# Gender                   0
# Height                   0
# Weight                   0
# Activity Level           0
# Dietary Preference       0
# Daily Calorie Target     0
# Protein                 41
# Sugar                   43
# Sodium                  34
# Calories                48
# Carbohydrates           47
# Fiber                   52
# Fat                     46
# dtype: int64

# %%
df_w = df_w.dropna(subset=['Protein'])
df_w.isna().sum()
# Out:
# Ages                     0
# Gender                   0
# Height                   0
# Weight                   0
# Activity Level           0
# Dietary Preference       0
# Daily Calorie Target     0
# Protein                  0
# Sugar                   41
# Sodium                  33
# Calories                46
# Carbohydrates           46
# Fiber                   51
# Fat                     46
# dtype: int64

# %%
df_w = df_w.dropna(subset=['Sugar'])
df_w.isna().sum()
# Out:
# Ages                     0
# Gender                   0
# Height                   0
# Weight                   0
# Activity Level           0
# Dietary Preference       0
# Daily Calorie Target     0
# Protein                  0
# Sugar                    0
# Sodium                  31
# Calories                46
# Carbohydrates           45
# Fiber                   50
# Fat                     44
# dtype: int64

# %%
df_w = df_w.dropna(subset=['Sodium'])
df_w.isna().sum()
# Out:
# Ages                     0
# Gender                   0
# Height                   0
# Weight                   0
# Activity Level           0
# Dietary Preference       0
# Daily Calorie Target     0
# Protein                  0
# Sugar                    0
# Sodium                   0
# Calories                43
# Carbohydrates           43
# Fiber                   49
# Fat                     43
# dtype: int64

# %%
df_w = df_w.dropna(subset=['Calories'])
df_w.isna().sum()
# Out:
# Ages                     0
# Gender                   0
# Height                   0
# Weight                   0
# Activity Level           0
# Dietary Preference       0
# Daily Calorie Target     0
# Protein                  0
# Sugar                    0
# Sodium                   0
# Calories                 0
# Carbohydrates           41
# Fiber                   47
# Fat                     43
# dtype: int64

# %%
df_w = df_w.dropna(subset=['Carbohydrates'])
df_w.isna().sum()
# Out:
# Ages                     0
# Gender                   0
# Height                   0
# Weight                   0
# Activity Level           0
# Dietary Preference       0
# Daily Calorie Target     0
# Protein                  0
# Sugar                    0
# Sodium                   0
# Calories                 0
# Carbohydrates            0
# Fiber                   44
# Fat                     41
# dtype: int64

# %%
df_w = df_w.dropna(subset=['Fiber'])
df_w.isna().sum()
# Out:
# Ages                     0
# Gender                   0
# Height                   0
# Weight                   0
# Activity Level           0
# Dietary Preference       0
# Daily Calorie Target     0
# Protein                  0
# Sugar                    0
# Sodium                   0
# Calories                 0
# Carbohydrates            0
# Fiber                    0
# Fat                     39
# dtype: int64

# %%
df_w = df_w.dropna(subset=['Fat'])
df_w.isna().sum()
# Out:
# Ages                    0
# Gender                  0
# Height                  0
# Weight                  0
# Activity Level          0
# Dietary Preference      0
# Daily Calorie Target    0
# Protein                 0
# Sugar                   0
# Sodium                  0
# Calories                0
# Carbohydrates           0
# Fiber                   0
# Fat                     0
# dtype: int64

# %%
df_w.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1261 entries, 0 to 1697
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Ages                  1261 non-null   int64
#  1   Gender                1261 non-null   object
#  2   Height                1261 non-null   float64
#  3   Weight                1261 non-null   float64
#  4   Activity Level        1261 non-null   object
#  5   Dietary Preference    1261 non-null   object
#  6   Daily Calorie Target  1261 non-null   float64
#  7   Protein               1261 non-null   float64
#  8   Sugar                 1261 non-null   float64
#  9   Sodium                1261 non-null   float64
#  10  Calories              1261 non-null   float64
#  11  Carbohydrates         1261 non-null   float64
#  12  Fiber                 1261 non-null   float64
#  13  Fat                   1261 non-null   float64
# dtypes: float64(10), int64(1), object(3)
# ...

# %% [markdown]
# Saving of Dataset

# %%
df_w.to_csv(r"raw\Food_And_Nutrition-Cleaned.csv",
            index=False)

# %% [markdown]
# # Data Visualization

# %%
df = pd.read_csv("raw\Food_And_Nutrition-Cleaned.csv",
                delimiter=",")
df_v = df
df_v.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1261 entries, 0 to 1260
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Ages                  1261 non-null   int64
#  1   Gender                1261 non-null   object
#  2   Height                1261 non-null   float64
#  3   Weight                1261 non-null   float64
#  4   Activity Level        1261 non-null   object
#  5   Dietary Preference    1261 non-null   object
#  6   Daily Calorie Target  1261 non-null   float64
#  7   Protein               1261 non-null   float64
#  8   Sugar                 1261 non-null   float64
#  9   Sodium                1261 non-null   float64
#  10  Calories              1261 non-null   float64
#  11  Carbohydrates         1261 non-null   float64
#  12  Fiber                 1261 non-null   float64
#  13  Fat                   1261 non-null   float64
# dtypes: float64(10), int64(1), object(3)
# ...

# %%
df_v.head()
# Out:
#    Ages  Gender  Height  Weight     Activity Level Dietary Preference  \
# 0    25    Male   180.0    80.0  Moderately Active           Omnivore
# 1    32  Female   165.0    65.0     Lightly Active         Vegetarian
# 2    62    Male   170.0    85.0          Sedentary         Vegetarian
# 3    68  Female   155.0    60.0     Lightly Active              Vegan
# 4    28    Male   190.0   100.0  Moderately Active           Omnivore
#
#    Daily Calorie Target  Protein  Sugar  Sodium  Calories  Carbohydrates  \
# 0                2000.0    120.0  125.0    24.0    2020.0          250.0
# 1                1600.0     80.0  100.0    16.0    1480.0          200.0
# 2                2000.0     80.0  125.0    16.0    1815.0          250.0
# 3                1800.0     70.0  110.0    14.0    1565.0          220.0
# 4                3000.0    180.0  175.0    36.0    2840.0          350.0
#
#    Fiber   Fat
# 0   30.0  60.0
# 1   24.0  40.0
# 2   30.0  55.0
# 3   26.4  45.0
# 4   42.0  80.0

# %% [markdown]
# # Body Mass Index (BMI)

# %%
df['Height'] = df['Height'] / 100
df['BMI'] = df['Weight'] / (df['Height'] ** 2)

def categorize_bmi(bmi):
    if bmi < 18.5:
        return "Underweight"
    elif 18.5 <= bmi < 25:
        return "Normal weight"
    elif 25 <= bmi < 30:
        return "Overweight"
    else:
        return "Obese"
    
df['BMI Category'] = df['BMI'].apply(categorize_bmi)
bmi_counts = df['BMI Category'].value_counts()

plt.figure(figsize=(8, 8))
plt.pie(
    bmi_counts, 
    labels=bmi_counts.index, 
    autopct='%1.1f%%', 
    startangle=140, 
    colors=['lightblue', 'lightgreen', 'orange', 'red']
)
plt.title("Overall BMI Distribution")
plt.show()

# %% [markdown]
# Split Into Genders

# %%
df_male = df[df['Gender'] == 'Male']
df_female = df[df['Gender'] == 'Female']

bmi_counts_male = df_male['BMI Category'].value_counts()
bmi_counts_female = df_female['BMI Category'].value_counts()

fig, axes = plt.subplots(1, 2, figsize=(14, 7))

axes[0].pie(
    bmi_counts_male, 
    labels=bmi_counts_male.index, 
    autopct='%1.1f%%', 
    startangle=140, 
    colors=['lightblue', 'lightgreen', 'orange', 'pink']
)
axes[0].set_title('BMI Distribution for Males', fontweight = "bold")

axes[1].pie(
    bmi_counts_female, 
    labels=bmi_counts_female.index, 
    autopct='%1.1f%%', 
    startangle=140, 
    colors=['lightblue', 'lightgreen', 'orange', 'pink']
)
axes[1].set_title('BMI Distribution for Females', fontweight = "bold")

plt.tight_layout()
plt.show()

# %% [markdown]
# Split into Age Groups

# %%
df_a = df[(df["Ages"] >= 18) & (df["Ages"] <= 30)]
df_b = df[(df["Ages"] >= 31) & (df["Ages"] <= 43)]
df_c = df[(df["Ages"] >= 44) & (df["Ages"] <= 55)]
df_d = df[(df["Ages"] >= 56) & (df["Ages"] <= 67)]
df_e = df[(df["Ages"] >= 68) & (df["Ages"] <= 79)]

bmi_a = df_a['BMI Category'].value_counts()
bmi_b = df_b['BMI Category'].value_counts()
bmi_c = df_c['BMI Category'].value_counts()
bmi_d = df_d['BMI Category'].value_counts()
bmi_e = df_e['BMI Category'].value_counts()

fig, axes = plt.subplots(1, 5, figsize=(20, 5))

axes[0].pie(
    bmi_a,
    labels=bmi_a.index,
    autopct='%1.1f%%', 
    startangle=140, 
    colors=['lightblue', 'lightgreen', 'orange', 'red']
)
axes[1].pie(
    bmi_b,
    labels=bmi_a.index,
    autopct='%1.1f%%', 
    startangle=140, 
    colors=['lightblue', 'lightgreen', 'orange', 'red']
)
axes[2].pie(
    bmi_c,
    labels=bmi_a.index,
    autopct='%1.1f%%', 
    startangle=140, 
    colors=['lightblue', 'lightgreen', 'orange', 'red']
)
axes[3].pie(
    bmi_d,
    labels=bmi_a.index,
    autopct='%1.1f%%', 
    startangle=140, 
    colors=['lightblue', 'lightgreen', 'orange', 'red']
)
axes[4].pie(
    bmi_e,
    labels=bmi_a.index,
    autopct='%1.1f%%', 
    startangle=140, 
    colors=['lightblue', 'lightgreen', 'orange', 'red']
)
axes[0].set_title('18-30\nYears old')
axes[1].set_title('31-43\nYears old')
axes[2].set_title('44-55\nYears old')
axes[3].set_title('56-67\nYears old')
axes[4].set_title('68-79\nYears old')
fig.suptitle("BMI Distribution by Age Group", fontsize=16, fontweight='bold')
plt.show()

# %% [markdown]
# BMI Distribution by Dietary Preferences

# %%
df_f = df[df["Dietary Preference"] == "Omnivore"]
df_g = df[df["Dietary Preference"] == "Pescatarian"]
df_h=  df[df["Dietary Preference"] == "Vegan"]
df_i= df[df["Dietary Preference"] == "Vegetarian"]

bmi_Omni = df_f['BMI Category'].value_counts()
bmi_Pesca = df_g['BMI Category'].value_counts()
bmi_Vegan = df_h['BMI Category'].value_counts()
bmi_Vege = df_i['BMI Category'].value_counts()

fig, axes = plt.subplots(1, 4, figsize=(20, 5))
axes[0].pie(
    bmi_Omni,
    labels=bmi_Omni.index,
    autopct='%1.1f%%', 
    startangle=140, 
    colors=['lightblue', 'lightgreen', 'orange', 'red']
)
axes[1].pie(
    bmi_Pesca,
    labels=bmi_Omni.index,
    autopct='%1.1f%%', 
    startangle=140, 
    colors=['lightblue', 'lightgreen', 'orange', 'red']
)
axes[2].pie(
    bmi_Vegan,
    labels=bmi_Omni.index,
    autopct='%1.1f%%', 
    startangle=140, 
    colors=['lightblue', 'lightgreen', 'orange', 'red']
)
axes[3].pie(
    bmi_Vege,
    labels=bmi_Omni.index,
    autopct='%1.1f%%', 
    startangle=140, 
    colors=['lightblue', 'lightgreen', 'orange', 'red']
)

fig.suptitle("BMI Distribution by Dietary Preference", fontsize=16, fontweight='bold')

plt.show()

# %% [markdown]
# BMI by Activity Level

# %%
activity_levels = ["Sedentary", "Lightly Active", "Moderately Active", "Very Active", "Extremely Active"]
bmi_categories = ["Underweight", "Normal weight", "Overweight", "Obese"]

fig, axes = plt.subplots(1, 5, figsize=(20, 5))

for i, activity in enumerate(activity_levels[:5]):
    subset = df[df["Activity Level"] == activity]["BMI Category"].value_counts()
    subset = subset.reindex(bmi_categories, fill_value=0) 

    axes[i].pie(subset.values, labels=subset.index, autopct='%1.1f%%',
                colors=['skyblue', 'lightgreen', 'orange', 'red'])
    axes[i].set_title(f"{activity}", fontsize=12, fontweight="bold")

fig.suptitle("BMI Distribution by Activity Level", fontsize=16, fontweight="bold")

plt.show()

# %% [markdown]
# # Activity Level

# %%
activity_counts = df["Activity Level"].value_counts(normalize=True) * 100
activity_counts
# Out:
# Activity Level
# Moderately Active    25.059477
# Sedentary            23.949247
# Lightly Active       23.552736
# Very Active          19.349722
# Extremely Active      8.088818
# Name: proportion, dtype: float64

# %%
color = ['#344E41','#3A5A40','#588157','#A3B18A','#DAD7CD']

plt.figure(figsize=(7, 9))
plt.bar(activity_counts.index, activity_counts.values, color=color)

plt.xlabel("Activity Level", fontweight = "bold")
plt.ylabel("Count", fontweight = "bold")
plt.title("Distribution of Activity Levels", fontsize=14, fontweight='bold')
plt.xticks(rotation=20)

for i, v in enumerate(activity_counts.values):
    plt.text(i, v + 1, f"{v:.1f}%", ha='center', fontsize=10)

plt.show()

# %% [markdown]
# Activity Level by Gender

# %%
genders = sorted(df["Gender"].unique())

fig, axes = plt.subplots(1, 2, figsize=(12, 5), sharey=True)

colors = {
    "Lightly Active": "blue",
    "Sedentary": "red",
    "Moderately Active": "green",
    "Very Active": "orange",
    "Extremely Active": "purple"
}

for i, gender in enumerate(genders):
    subset = df[df["Gender"] == gender]["Activity Level"].value_counts(normalize=True) * 100

    subset = subset.reindex(colors.keys(), fill_value=0)

    axes[i].bar(subset.index, subset.values, color=[colors[act] for act in subset.index])
    axes[i].set_title(f"{gender}", fontsize=12, fontweight="bold")
    axes[i].set_xticklabels(subset.index, rotation=20)
    axes[i].set_ylim(0, 100)

fig.suptitle("Activity Level Distribution by Gender", fontsize=14, fontweight="bold")

axes[0].set_ylabel("Percentage (%)")

plt.tight_layout()
plt.show()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_22180\930889140.py:20: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[i].set_xticklabels(subset.index, rotation=20)
# C:\Users\PC\AppData\Local\Temp\ipykernel_22180\930889140.py:20: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[i].set_xticklabels(subset.index, rotation=20)

# %% [markdown]
# # Nutrient Intake

# %%
plt.figure(figsize=(9, 6))
plt.scatter(df['Daily Calorie Target'], range(len(df)), marker='o', color='purple')
plt.xlabel('Daily Calorie Intake', fontweight = "bold")
plt.ylabel('Number of People', fontweight = "bold")
plt.title('Scatter Plot of Daily Calorie Target (1200cal to 4400cal)', fontweight = "bold")
plt.grid()
plt.show()

# %% [markdown]
# Daily Calorie Target by Activity Level

# %%
color = ['#6D6875','#B5838D','#E5989B','#FFB4A2','#FFCDB2']
activity_levels = df['Activity Level'].unique()
avg_calories = [df[df['Activity Level'] == level]['Daily Calorie Target'].mean() for level in activity_levels]

sorted_indices = np.argsort(avg_calories)
activity_levels = np.array(activity_levels)[sorted_indices]
avg_calories = np.array(avg_calories)[sorted_indices]

plt.figure(figsize=(9, 6))
plt.barh(activity_levels, avg_calories, color=color)

plt.xlabel('Average Daily Calorie Target', fontweight = "bold")
plt.ylabel('Activity Level', fontweight = "bold")
plt.title('Average Daily Calorie Target by Activity Level', fontweight = "bold")

plt.grid(axis='x', linestyle='-', alpha=0.7)
plt.show()

# %% [markdown]
# Daily Calorie Target by Dietary Preference

# %%
# Step 1: Calculate required protein intake
df['Required Protein Intake'] = df['Weight'] * 2.2

# Step 2: Create a column to check if they meet their requirement
df['Meets Protein Target'] = df['Protein'] >= df['Required Protein Intake']

# Step 3: Count how many meet vs. don't meet the target
counts = df['Meets Protein Target'].value_counts()

# Step 4: Plot the pie chart
plt.figure(figsize=(6, 6))
plt.pie(counts, labels=['Meets Target', 'Does Not Meet Target'], autopct='%1.1f%%', colors=['#98FF98', '#FFB4A2'])
plt.title('Percentage of People Who Meet Their Protein Intake', fontweight = "bold")
plt.show()

# %% [markdown]
# Percentage of who is maintaing weight, losing weight, and gaining weight

# %%
df['Estimated Maintenance Calories'] = df['Weight'] * 30.8
calorie_diff = df['Daily Calorie Target'] - df['Estimated Maintenance Calories']

weight_status = []
for diff in calorie_diff:
    if diff > 200:
        weight_status.append('Gaining Weight')
    elif diff < -200:
        weight_status.append('Losing Weight')
    else:
        weight_status.append('Maintaining Weight')

df['Weight Status'] = weight_status

counts = df['Weight Status'].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(counts, labels=counts.index, autopct='%1.1f%%', colors=['#dd6e42', '#e8dab2', '#4f6d7a'])
plt.title('Weight Status Based on Calorie Intake', fontweight = "bold")
plt.show()

# %% [markdown]
# Sodium Intake by Age Group

# %%
color = ['#05668D','#028090','#00A896','#02C39A','#F0F3BD']
age_labels = ['18-30', '31-43', '44-55', '56-67', '68-79']
df['Age Group'] = pd.cut(df['Ages'], bins=[18, 30, 43, 55, 67, 79], labels=age_labels, include_lowest=True)

avg_sodium = df.groupby('Age Group')['Sodium'].mean()

plt.figure(figsize=(8, 5))
plt.bar(avg_sodium.index, avg_sodium.values, color=color)

plt.xlabel('Age Group', fontweight = "bold")
plt.ylabel('Average Sodium Intake', fontweight = "bold")
plt.title('Average Sodium Intake by Age Group', fontweight = "bold")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='-', alpha=0.7)
plt.show()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_22180\3178038051.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_sodium = df.groupby('Age Group')['Sodium'].mean()

# %%
age_labels = ['18-30', '31-43', '44-55', '56-67', '68-79']
df['Age Group'] = pd.cut(df['Ages'], bins=[18, 30, 43, 55, 67, 79], labels=age_labels, include_lowest=True)

avg_sugar = df.groupby('Age Group')['Sugar'].mean()

plt.figure(figsize=(8, 5))
plt.bar(avg_sugar.index, avg_sugar.values, color=color)

plt.xlabel('Age Group', fontweight = "bold")
plt.ylabel('Average Sugar Intake', fontweight = "bold")
plt.title('Average Sugar Intake by Age Group', fontweight = "bold")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='-', alpha=0.7)
plt.show()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_22180\380968058.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_sugar = df.groupby('Age Group')['Sugar'].mean()

# %%
age_labels = ['18-30', '31-43', '44-55', '56-67', '68-79']
df['Age Group'] = pd.cut(df['Ages'], bins=[18, 30, 43, 55, 67, 79], labels=age_labels, include_lowest=True)

avg_fat = df.groupby('Age Group')['Fat'].mean()

plt.figure(figsize=(8, 5))
plt.bar(avg_fat.index, avg_fat.values, color=color)

plt.xlabel('Age Group', fontweight = "bold")
plt.ylabel('Average Fat Intake', fontweight = "bold")
plt.title('Average Fat Intake by Age Group', fontweight = "bold")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='-', alpha=0.7)
plt.show()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_22180\928694488.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_fat = df.groupby('Age Group')['Fat'].mean()

# %%
age_labels = ['18-30', '31-43', '44-55', '56-67', '68-79']
df['Age Group'] = pd.cut(df['Ages'], bins=[18, 30, 43, 55, 67, 79], labels=age_labels, include_lowest=True)

avg_fibre = df.groupby('Age Group')['Fiber'].mean()

plt.figure(figsize=(8, 5))
plt.bar(avg_fibre.index, avg_fibre.values, color=color)

plt.xlabel('Age Group', fontweight = "bold")
plt.ylabel('Average Fiber Intake', fontweight = "bold")
plt.title('Average Fiber Intake by Age Group', fontweight = "bold")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='-', alpha=0.7)
plt.show()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_22180\1195193657.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_fibre = df.groupby('Age Group')['Fiber'].mean()
